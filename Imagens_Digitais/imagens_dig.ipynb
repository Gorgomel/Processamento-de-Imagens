# %%
# !pip install opencv-python

# %% [markdown]
# # Exercício

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import image

# %%
img1 = cv2.imread('image.jpg', 1)

# %%
img1.shape
# Out:
# (389, 389, 3)

# %%
channels = img1.shape[2]
print('Quantidade de Canais: {}'. format(channels))
# Out:
# Quantidade de Canais: 3

# %%
img1 = cv2.imread('image.jpg', 1)

# %%
plt.imshow(cv2.cvtColor(img1, cv2.COLOR_BGR2RGB))
plt.axis('off')
# Out:
# (-0.5, 388.5, 388.5, -0.5)

# %%
img1[0 : 194, 0 : 194] = (0, 255, 255)

# %%
img1[194 : 388, 194 : 388] = (0, 0, 0)

# %%
img1[5 : 20, 5 : 20] = (0, 0, 255)

# %%
plt.imshow(cv2.cvtColor(img1, cv2.COLOR_BGR2RGB))

# %%
cv2.imwrite("imagemplot.png", img1)
# Out:
# True

# %%
img1 = cv2.imread('image.jpg')

# %%
plt.imshow(cv2.cvtColor(img1, cv2.COLOR_BGR2RGB))

# %%
iB, iG, iR = cv2.split(img1)

# %%
red = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)

# %%
red[:, :, 1] = 0
red[:, :, 2] = 0

# %%
plt.imshow(red)
plt.axis('off')
# Out:
# (-0.5, 388.5, 388.5, -0.5)

# %%
green = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)

# %%
green[:, :, 0] = 0
green[:, :, 2] = 0

# %%
plt.imshow(green)
plt.axis('off')
# Out:
# (-0.5, 388.5, 388.5, -0.5)

# %%
blue = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)

# %%
blue[:, :, 0] = 0
blue[:, :, 1] = 0

# %%
plt.imshow(blue)
plt.axis('off')
# Out:
# (-0.5, 388.5, 388.5, -0.5)

# %%
red[:, :, 1] = 0
red[:, :, 2] = 0
red[:, :, 0] = red[:, :, 0] %128
red_bgr = cv2.cvtColor(red, cv2.COLOR_RGB2BGR)

# %%
blue[:, :, 0] = 0
blue[:, :, 1] = 0
blue[:, :, 2] = blue[:, :, 2] + 10
blue_bgr = cv2.cvtColor(blue, cv2.COLOR_BGR2RGB)

# %%
green[:, :, 0] = 0
green[:, :, 2] = 0
green[:, :, 1] = np.abs(green[:, :, 1] - 15)
green_bgr = cv2.cvtColor(green, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(red)
plt.axis('off')
# Out:
# (-0.5, 388.5, 388.5, -0.5)

# %%
plt.imshow(blue)
plt.axis('off')
# Out:
# (-0.5, 388.5, 388.5, -0.5)

# %%
plt.imshow(green)
plt.axis('off')
# Out:
# (-0.5, 388.5, 388.5, -0.5)

# %%
cv2.imwrite("red_bgr.png", red_bgr)
cv2.imwrite("blue_bgr.png", blue_bgr)
cv2.imwrite("green_bgr.png", green_bgr)
# Out:
# True

# %%
img1 = cv2.imread('image.jpg')

# %%
plt.imshow(cv2.cvtColor(img1, cv2.COLOR_BGR2RGB))
plt.axis('off')
# Out:
# (-0.5, 388.5, 388.5, -0.5)

# %%
cv2.line(img1, (0, 100), (389, 100), (255, 0, 0), 2)
# Out:
# array([[[ 76, 112, 152],
#         [ 81, 117, 157],
#         [ 84, 119, 163],
#         ...,
#         [123, 135, 117],
#         [163, 175, 157],
#         [193, 205, 187]],
#
#        [[ 77, 113, 153],
#         [ 78, 114, 154],
#         [ 77, 112, 155],
#         ...,
#         [140, 150, 133],
#         [179, 190, 170],
#         [203, 213, 196]],
#
#        [[ 78, 115, 153],
#         [ 74, 110, 150],
#         [ 69, 105, 145],
#         ...,
#         [168, 177, 157],
#         [202, 211, 190],
#         [216, 225, 205]],
#
#        ...,
#
#        [[233, 232, 204],
#         [233, 233, 203],
#         [222, 222, 192],
#         ...,
#         [ 73,  75,  85],
#         [ 89,  97, 114],
#         [ 84,  97, 123]],
#
#        [[229, 228, 200],
#         [235, 235, 205],
#         [220, 220, 190],
#         ...,
#         [ 21,  23,  33],
#         [ 26,  34,  51],
#         [ 25,  38,  64]],
#
#        [[228, 227, 199],
#         [237, 237, 207],
#         [219, 219, 189],
# ...

# %%
cv2.circle(img1, (180, 180), 120, (0, 0, 255), 2)
# Out:
# array([[[ 76, 112, 152],
#         [ 81, 117, 157],
#         [ 84, 119, 163],
#         ...,
#         [123, 135, 117],
#         [163, 175, 157],
#         [193, 205, 187]],
#
#        [[ 77, 113, 153],
#         [ 78, 114, 154],
#         [ 77, 112, 155],
#         ...,
#         [140, 150, 133],
#         [179, 190, 170],
#         [203, 213, 196]],
#
#        [[ 78, 115, 153],
#         [ 74, 110, 150],
#         [ 69, 105, 145],
#         ...,
#         [168, 177, 157],
#         [202, 211, 190],
#         [216, 225, 205]],
#
#        ...,
#
#        [[233, 232, 204],
#         [233, 233, 203],
#         [222, 222, 192],
#         ...,
#         [ 73,  75,  85],
#         [ 89,  97, 114],
#         [ 84,  97, 123]],
#
#        [[229, 228, 200],
#         [235, 235, 205],
#         [220, 220, 190],
#         ...,
#         [ 21,  23,  33],
#         [ 26,  34,  51],
#         [ 25,  38,  64]],
#
#        [[228, 227, 199],
#         [237, 237, 207],
#         [219, 219, 189],
# ...

# %%
cv2.rectangle(img1, (100, 100), (260, 270), (0, 255, 0), 2)
# Out:
# array([[[ 76, 112, 152],
#         [ 81, 117, 157],
#         [ 84, 119, 163],
#         ...,
#         [123, 135, 117],
#         [163, 175, 157],
#         [193, 205, 187]],
#
#        [[ 77, 113, 153],
#         [ 78, 114, 154],
#         [ 77, 112, 155],
#         ...,
#         [140, 150, 133],
#         [179, 190, 170],
#         [203, 213, 196]],
#
#        [[ 78, 115, 153],
#         [ 74, 110, 150],
#         [ 69, 105, 145],
#         ...,
#         [168, 177, 157],
#         [202, 211, 190],
#         [216, 225, 205]],
#
#        ...,
#
#        [[233, 232, 204],
#         [233, 233, 203],
#         [222, 222, 192],
#         ...,
#         [ 73,  75,  85],
#         [ 89,  97, 114],
#         [ 84,  97, 123]],
#
#        [[229, 228, 200],
#         [235, 235, 205],
#         [220, 220, 190],
#         ...,
#         [ 21,  23,  33],
#         [ 26,  34,  51],
#         [ 25,  38,  64]],
#
#        [[228, 227, 199],
#         [237, 237, 207],
#         [219, 219, 189],
# ...

# %%
plt.imshow(cv2.cvtColor(img1, cv2.COLOR_BGR2RGB))
plt.axis('off')
# Out:
# (-0.5, 388.5, 388.5, -0.5)

# %%
cv2.imwrite("imageFormas.png", img1)
# Out:
# True
